# %% [markdown]
# ### Deriving New Variables

# %% [markdown]
#     1. Import libraries and dataframes
#     2. Create a subset to limit ram usage
#     3. Define a new column, price label
#     4. Apply the new defined function
#     5. Using the loc() function
#     6. Review the frequency of items bought on each day of the week
#     7. Create new column
#     8. Redefine new columns
#     9. Identify busiest hours of the day labeled as 'busiest_period_of_day'

# %% [markdown]
#    1. Import libraries and dataframes

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
# shortcut the main file to path
path = r'C:\Users\dodge\24-06-2023 Instacart Basket Analysis'

# %%
ord

# %% [markdown]
#    2. Create a subset of the first million rows

# %%
# define a subset of rows
df=df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# 3. Define a new column, price label

# %%
#Define a function
def price_label(row):
    
    if row['prices'] <= 5:
        return 'low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %% [markdown]
# 4. Apply the defined function

# %%
#Apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\dodge\AppData\Local\Temp\ipykernel_12516\3959542531.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# low range product    243550
# Name: price_range, dtype: int64

# %%
#Check the max price in selected rows
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
#  5. Using the loc() function

# %%
# Using the loc() function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'
# Out:
# C:\Users\dodge\AppData\Local\Temp\ipykernel_12516\2419128129.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] >5), 'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <=5, 'price_range_loc'] = 'Low range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Use the loc function on the entire dataframe instead of a subset
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# 6. Review the frequency of items bought on each day of the week

# %%
df_ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %% [markdown]
#  7. Create a new column to classfiy the busiest day of the week

# %%
# Create a new column with three different values
result = []

for value in df_ords_prods_merged["order_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
# review the output
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#Create a new column in dataframe and set to result
df_ords_prods_merged["Busiest_day"] = result

# %%
# Check the output
df_ords_prods_merged['Busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest_day, dtype: int64

# %% [markdown]
# Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %% [markdown]
# 8. Recreate new columns

# %%
# Define busiest days to include more than one day
results = []

for value in df_ords_prods_merged["order_day_of_week"]:
    if value == 0 or value == 1:
        results.append("Busiest_day")
    elif value == 4 or value == 3:
        results.append("Least_busy")
    else:
        results.append("Regularly_busy")

# %%
#Create a new column in dataframe and set to results
df_ords_prods_merged['Busiest_day'] = results

# %%
# Check the output
df_ords_prods_merged['Busiest_day'].value_counts(dropna = False)
# Out:
# Regularly_busy    12916111
# Busiest_day       11864412
# Least_busy         7624336
# Name: Busiest_day, dtype: int64

# %% [markdown]
# Both busiest_day and least_busy are higher in value than previously as they now represent two days each.  Where regularly_busy has decreased in number.  They equal the same number of overall entries (32,404,859)

# %% [markdown]
# When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %% [markdown]
#   9. Identify busiest hours of the day labeled as 'busiest_period_of_day'

# %%
# Identify headers of data frame
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# Determine the busiest hours when orders are placed
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# There are different ways to group the hours of the day for classification as most, average, fewest:  you could do quartiles, do by millions (fewer than 750K; 750K-2.5 million; greater than 2.5 million); group by top 8, middle 8, bottom 8; review statistics of the counts and determine equal spread from the average to the max-min.

# %%
#Create a dataframe with the count of the number of order per hour
count = df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)

# %%
count.describe()
# Out:
# count    2.400000e+01
# mean     1.350202e+06
# std      1.078369e+06
# min      5.128100e+04
# 25%      2.725620e+05
# 50%      1.117230e+06
# 75%      2.556034e+06
# max      2.761760e+06
# Name: order_hour_of_day, dtype: float64

# %% [markdown]
# Average = 1,350,202.  Standard deviation = 1,078,369.  So I will define the most orders per hour as anything greater than 2,428,571 (mean + std); fewest will be anything less than 271,833 (mean - std); everything in between will be considered average.

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
count
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# Define busiest period of day to include orders placed per defined criteria
busy_hours = []

for value in df_ords_prods_merged['order_hour_of_day']:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        busy_hours.append('Most_orders')
    elif value in [0, 1, 5, 2, 4, 3]:
        busy_hours.append('Fewest_orders')
    else:
        busy_hours.append('Average_orders')

# %%
#Create a new column in dataframe and set to busy hours
df_ords_prods_merged['Busiest_period_of_day'] = busy_hours

# %% [markdown]
# Print the frequency of new column

# %%
#Check the output
df_ords_prods_merged['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders       21118071
# Average_orders    10690460
# Fewest_orders       596328
# Name: Busiest_period_of_day, dtype: int64

# %%
#Review output in dataframe
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
#Export as pkl file
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_adds.pkl'))
